# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %%
import cv2
import numpy as np
import imutils
from google.colab.patches import cv2_imshow

# %%
# membaca file
image = cv2.imread('/gdrive/My Drive/Dataset/LidahBuaya.jpg')

# %%
# Menampilkan gambar
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=1600x1200 at 0x7FDA5D7D2190>

# %%
# Untuk mengetahui lebar dan tingginya
print(image.shape)
# Out:
# (1200, 1600, 3)

# %%
# Resize image (mempertahankan efek rasio)
resized_1 = imutils.resize(image, width=500)
cv2_imshow(resized_1)
# Out:
# <PIL.Image.Image image mode=RGB size=500x375 at 0x7FDA5B6CA410>

# %%
# Save image
cv2.imwrite('/gdrive/My Drive/Dataset/ModifikasiLidahBuaya.jpg', resized_1)
# Out:
# True

# %%
# Resize image without aspect ratio
resized_2 = cv2.resize(image, (500,500))
cv2_imshow(resized_2)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7FDA5CF55690>

# %%
import matplotlib.pyplot as plt
plt.imshow(resized_1)

# %%
modify = cv2.imread('/gdrive/My Drive/Dataset/ModifikasiLidahBuaya.jpg', cv2.IMREAD_GRAYSCALE)
cv2_imshow(modify)
# Out:
# <PIL.Image.Image image mode=L size=500x375 at 0x7FDA5B669D50>

# %%
print(resized_1.shape)
# Out:
# (375, 500, 3)

# %%
cv2.imwrite('/gdrive/My Drive/Dataset/ModifikasiLidahBuaya2.jpg',modify)
# Out:
# True

# %%
# Crop image
image2 = cv2.imread('/gdrive/My Drive/Dataset/ModifikasiLidahBuaya2.jpg')

crop = image2[10:400,10:500]
cv2_imshow(crop)
# Out:
# <PIL.Image.Image image mode=RGB size=490x365 at 0x7FDA5B688310>

# %%
print(crop.shape)
# Out:
# (365, 490, 3)
